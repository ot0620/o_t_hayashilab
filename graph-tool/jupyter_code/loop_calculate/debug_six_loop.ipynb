# %%
from graph_tool.all import Graph
from graph_tool.all import *
import graph_tool.all as gt
from tqdm import tqdm

# %%
Node = 100

m = 2

times = 10

beta_list = [1,0,-1,-100]

net_list = ["SF", "RA", "IPA_beta1", "IPA_beta100"]

# %%
from graph_tool.all import Graph

def find_paths(graph, start, length):
    """6回の移動で出発点に戻ってくる経路を探索"""
    paths = []

    def dfs(current, path):
        if len(path) == length + 1:  # 出発点含め7ノードを通る（移動回数6）
            if path[0] == path[-1]:  # 出発点に戻る
                paths.append(path)
            return

        for neighbor in graph.vertex(int(current)).out_neighbors():
            dfs(str(neighbor), path + [str(neighbor)])

    dfs(start, [start])
    return paths

# %%
for net in net_list:
    for i in tqdm(range(times)):    
        g = load_graph(f"~/o_t_hayashilab/Network_data/graph-tool/pure_pk/N={Node}/m={m}/{net}/{i}.gt.gz")

        # 結果の計算
        all_paths = []
        for start in range(g.num_vertices()):
            all_paths.extend(find_paths(g, str(start), 6))

        # 結果の出力
        print(f"条件を満たす経路の総数: {len(all_paths)}")
        #for path in all_paths:
            #print(" -> ".join(path))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:14<02:13, 14.82s/it]
# 条件を満たす経路の総数: 207166
#  20%|██        | 2/10 [00:29<01:56, 14.52s/it]
# 条件を満たす経路の総数: 195772
#  30%|███       | 3/10 [00:42<01:38, 14.07s/it]
# 条件を満たす経路の総数: 184612
#  40%|████      | 4/10 [01:00<01:32, 15.37s/it]
# 条件を満たす経路の総数: 250354
#  50%|█████     | 5/10 [01:18<01:22, 16.49s/it]
# 条件を満たす経路の総数: 270556
#  60%|██████    | 6/10 [01:32<01:02, 15.66s/it]
# 条件を満たす経路の総数: 197968
#  70%|███████   | 7/10 [01:48<00:47, 15.89s/it]
# 条件を満たす経路の総数: 233518
#  80%|████████  | 8/10 [02:06<00:32, 16.29s/it]
# 条件を満たす経路の総数: 242836
#  90%|█████████ | 9/10 [02:24<00:17, 17.05s/it]
# 条件を満たす経路の総数: 265066
# 100%|██████████| 10/10 [02:37<00:00, 15.76s/it]
# 条件を満たす経路の総数: 176548
#  10%|█         | 1/10 [00:03<00:35,  3.92s/it]
# 条件を満たす経路の総数: 59554
#  20%|██        | 2/10 [00:08<00:33,  4.15s/it]
# 条件を満たす経路の総数: 65062
#  30%|███       | 3/10 [00:12<00:30,  4.38s/it]
# 条件を満たす経路の総数: 70696
#  40%|████      | 4/10 [00:16<00:24,  4.12s/it]
# 条件を満たす経路の総数: 56824
#  50%|█████     | 5/10 [00:20<00:19,  3.91s/it]
# 条件を満たす経路の総数: 54664
#  60%|██████    | 6/10 [00:24<00:16,  4.20s/it]
# 条件を満たす経路の総数: 69502
#  70%|███████   | 7/10 [00:28<00:11,  3.96s/it]
# 条件を満たす経路の総数: 51442
#  80%|████████  | 8/10 [00:32<00:08,  4.03s/it]
# 条件を満たす経路の総数: 61018
#  90%|█████████ | 9/10 [00:36<00:04,  4.02s/it]
# 条件を満たす経路の総数: 62584
# 100%|██████████| 10/10 [00:41<00:00,  4.16s/it]
# 条件を満たす経路の総数: 73990
#  10%|█         | 1/10 [00:03<00:28,  3.15s/it]
# 条件を満たす経路の総数: 45154
#  20%|██        | 2/10 [00:05<00:22,  2.85s/it]
# 条件を満たす経路の総数: 41362
#  30%|███       | 3/10 [00:08<00:19,  2.75s/it]
# 条件を満たす経路の総数: 41734
#  40%|████      | 4/10 [00:11<00:16,  2.72s/it]
# 条件を満たす経路の総数: 41980
#  50%|█████     | 5/10 [00:13<00:13,  2.68s/it]
# 条件を満たす経路の総数: 41578
#  60%|██████    | 6/10 [00:16<00:10,  2.74s/it]
# 条件を満たす経路の総数: 43678
#  70%|███████   | 7/10 [00:19<00:08,  2.78s/it]
# 条件を満たす経路の総数: 45202
#  80%|████████  | 8/10 [00:21<00:05,  2.66s/it]
# 条件を満たす経路の総数: 37768
#  90%|█████████ | 9/10 [00:24<00:02,  2.58s/it]
# 条件を満たす経路の総数: 40042
# 100%|██████████| 10/10 [00:26<00:00,  2.69s/it]
# 条件を満たす経路の総数: 41506
#  10%|█         | 1/10 [00:01<00:11,  1.27s/it]
# 条件を満たす経路の総数: 24496
#  20%|██        | 2/10 [00:02<00:10,  1.28s/it]
# 条件を満たす経路の総数: 24586
#  30%|███       | 3/10 [00:03<00:09,  1.30s/it]
# 条件を満たす経路の総数: 25084
#  40%|████      | 4/10 [00:05<00:07,  1.29s/it]
# 条件を満たす経路の総数: 24082
#  50%|█████     | 5/10 [00:06<00:06,  1.29s/it]
# 条件を満たす経路の総数: 24850
#  60%|██████    | 6/10 [00:07<00:05,  1.29s/it]
# 条件を満たす経路の総数: 24784
#  70%|███████   | 7/10 [00:09<00:03,  1.30s/it]
# 条件を満たす経路の総数: 24904
#  80%|████████  | 8/10 [00:10<00:02,  1.29s/it]
# 条件を満たす経路の総数: 24316
#  90%|█████████ | 9/10 [00:11<00:01,  1.29s/it]
# 条件を満たす経路の総数: 24778
# 100%|██████████| 10/10 [00:12<00:00,  1.29s/it]
# 条件を満たす経路の総数: 24196

# %%
from graph_tool.all import Graph

def find_hexagonal_paths(graph, start, length):
    """6回の移動で出発点に戻る完全な6角形経路を探索"""
    paths = []

    def dfs(current, path):
        if len(path) == length + 1:  # 6回の移動（7ノード）
            if path[0] == path[-1]:  # 出発点に戻る
                paths.append(path)
            return

        for neighbor in graph.vertex(int(current)).out_neighbors():
            # ノードが重複しないように
            if str(neighbor) not in path or len(path) == length:
                dfs(str(neighbor), path + [str(neighbor)])

    dfs(start, [start])
    return paths

for net in net_list:
    for i in tqdm(range(times)):
        # グラフの読み込み
        g = load_graph(f"~/o_t_hayashilab/Network_data/graph-tool/pure_pk/N={Node}/m={m}/{net}/{i}.gt.gz")

        # 結果の計算
        hexagonal_paths = []
        for start in range(g.num_vertices()):
            hexagonal_paths.extend(find_hexagonal_paths(g, str(start), 6))

        # 結果の出力
        print(f"完全な6角形で経路を形成している経路の総数: {len(hexagonal_paths) / 12}")
        #for path in hexagonal_paths:
            #print(" -> ".join(path))
# Out:
#  10%|█         | 1/10 [00:05<00:49,  5.46s/it]
# 完全な6角形で経路を形成している経路の総数: 1916.0
#  20%|██        | 2/10 [00:10<00:40,  5.12s/it]
# 完全な6角形で経路を形成している経路の総数: 1482.0
#  30%|███       | 3/10 [00:15<00:34,  5.00s/it]
# 完全な6角形で経路を形成している経路の総数: 1506.0
#  40%|████      | 4/10 [00:21<00:32,  5.48s/it]
# 完全な6角形で経路を形成している経路の総数: 2477.0
#  50%|█████     | 5/10 [00:27<00:28,  5.73s/it]
# 完全な6角形で経路を形成している経路の総数: 2395.0
#  60%|██████    | 6/10 [00:32<00:21,  5.44s/it]
# 完全な6角形で経路を形成している経路の総数: 1459.0
#  70%|███████   | 7/10 [00:38<00:16,  5.62s/it]
# 完全な6角形で経路を形成している経路の総数: 2271.0
#  80%|████████  | 8/10 [00:44<00:11,  5.82s/it]
# 完全な6角形で経路を形成している経路の総数: 2428.0
#  90%|█████████ | 9/10 [00:51<00:06,  6.16s/it]
# 完全な6角形で経路を形成している経路の総数: 2612.0
# 100%|██████████| 10/10 [00:56<00:00,  5.62s/it]
# 完全な6角形で経路を形成している経路の総数: 1418.0
#  10%|█         | 1/10 [00:01<00:13,  1.54s/it]
# 完全な6角形で経路を形成している経路の総数: 362.0
#  20%|██        | 2/10 [00:03<00:12,  1.60s/it]
# 完全な6角形で経路を形成している経路の総数: 378.0
#  30%|███       | 3/10 [00:04<00:11,  1.70s/it]
# 完全な6角形で経路を形成している経路の総数: 424.0
#  40%|████      | 4/10 [00:06<00:09,  1.60s/it]
# 完全な6角形で経路を形成している経路の総数: 308.0
#  50%|█████     | 5/10 [00:07<00:07,  1.52s/it]
# 完全な6角形で経路を形成している経路の総数: 267.0
#  60%|██████    | 6/10 [00:09<00:06,  1.64s/it]
# 完全な6角形で経路を形成している経路の総数: 505.0
#  70%|███████   | 7/10 [00:11<00:04,  1.56s/it]
# 完全な6角形で経路を形成している経路の総数: 302.0
#  80%|████████  | 8/10 [00:12<00:03,  1.60s/it]
# 完全な6角形で経路を形成している経路の総数: 394.0
#  90%|█████████ | 9/10 [00:14<00:01,  1.58s/it]
# 完全な6角形で経路を形成している経路の総数: 342.0
# 100%|██████████| 10/10 [00:16<00:00,  1.63s/it]
# 完全な6角形で経路を形成している経路の総数: 501.0
#  10%|█         | 1/10 [00:01<00:10,  1.18s/it]
# 完全な6角形で経路を形成している経路の総数: 262.0
#  20%|██        | 2/10 [00:02<00:08,  1.06s/it]
# 完全な6角形で経路を形成している経路の総数: 180.0
#  30%|███       | 3/10 [00:03<00:07,  1.02s/it]
# 完全な6角形で経路を形成している経路の総数: 157.0
#  40%|████      | 4/10 [00:04<00:06,  1.04s/it]
# 完全な6角形で経路を形成している経路の総数: 223.0
#  50%|█████     | 5/10 [00:05<00:05,  1.02s/it]
# 完全な6角形で経路を形成している経路の総数: 189.0
#  60%|██████    | 6/10 [00:06<00:04,  1.04s/it]
# 完全な6角形で経路を形成している経路の総数: 203.0
#  70%|███████   | 7/10 [00:07<00:03,  1.06s/it]
# 完全な6角形で経路を形成している経路の総数: 201.0
#  80%|████████  | 8/10 [00:08<00:02,  1.00s/it]
# 完全な6角形で経路を形成している経路の総数: 145.0
#  90%|█████████ | 9/10 [00:09<00:00,  1.02it/s]
# 完全な6角形で経路を形成している経路の総数: 157.0
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# 完全な6角形で経路を形成している経路の総数: 171.0
#  10%|█         | 1/10 [00:00<00:04,  2.16it/s]
# 完全な6角形で経路を形成している経路の総数: 55.0
#  20%|██        | 2/10 [00:00<00:03,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 63.0
#  30%|███       | 3/10 [00:01<00:03,  2.15it/s]
# 完全な6角形で経路を形成している経路の総数: 61.0
#  40%|████      | 4/10 [00:01<00:02,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 59.0
#  50%|█████     | 5/10 [00:02<00:02,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 74.0
#  60%|██████    | 6/10 [00:02<00:01,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 57.0
#  70%|███████   | 7/10 [00:03<00:01,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 59.0
#  80%|████████  | 8/10 [00:03<00:00,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 64.0
#  90%|█████████ | 9/10 [00:04<00:00,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 52.0
# 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
# 完全な6角形で経路を形成している経路の総数: 56.0

# %%
gt.graph_draw(g, vertex_text = g.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7febe0df24e0, at 0x7febe0de9010>

# %%
from tqdm import tqdm
g = load_graph("/home/guest/o_t_hayashilab/Network_data/graph-tool/example_network/soc-karate.gt.gz")

node_id = 0

for i in range(g.num_vertices()):
    node_id_property = g.new_vertex_property("int")  # ノードIDを格納する新しいプロパティ

    node_id += 1  # 新しいノードIDを割り当てる
    node_id_property[g.vertex(i)] = node_id  # ノードIDをプロパティに格納

#このように、グラフを作る際に、各ノードに「node_id」を割り当てる必要がある

###
total_loop = 0
multiple_edge = 0
# グラフ g のすべてのノードとエッジを調査
for v in tqdm(g.vertices()):
    # 自己ループの検出
    if g.edge(v, v) is not None:
        print(f"ノード {int(g.vp.node_id[v])} に自己ループが存在します。")
        total_loop += 1

    # 多重リンクの検出
    for u in g.vertices():
        if u != v:
            edges = list(g.edge(v, u, all_edges=True))
            if len(edges) > 1:
                print(f"ノード {int(g.vp.node_id[v])} と {int(g.vp.node_id[u])} の間に多重リンクが存在します。")
                multiple_edge += 1

print(f"自己ループは{int(total_loop)}個あります。")
print(f"多重リンクは{int(multiple_edge)}個あります。")
# Out:
# 34it [00:00, 10682.12it/s]
# 自己ループは0個あります。
# 多重リンクは0個あります。
