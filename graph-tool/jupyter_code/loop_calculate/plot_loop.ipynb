# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# ベースとなるリスト
x_values = [3, 4, 5, 6]

# %%
# yリストを7つ生成
y_lists = [
    [109.56, 684.58, 4374.25, 28236.99],             # y1
    [25.83, 99.89, 423.87, 1837.94],              # y2
    [14.32, 49.27, 174.25, 636.42],              # y3
    [9.41, 26.06, 79.35, 249.33],              # y4
    [6.16, 15.69, 42.75, 119.6],              # y5
    [5.81, 14.57, 36.85, 103.2],              # y6
    [4.42, 9.75, 23.79, 59.42]                # y7
]

y_name = ["ν = 1", "ν = 1/2", "ν = 0", "ν = -1", "ν = -3", "ν = -4", "ν = -100"]

# 色とラベルを設定
colors = ['red', 'darkorange', 'yellow', 'green', 'aqua', 'blue', 'purple']
labels = [f'{y_name[i]}' for i in range(7)]

# プロット
plt.figure(figsize=(8, 6))  # グラフのサイズを設定
for i, (y, color, label) in enumerate(zip(y_lists, colors, labels)):
    plt.semilogy(x, y, marker='o', linestyle='-', color=color, label=label)

plt.title('m = 2')

# x軸の目盛り設定
plt.xticks(ticks=[3, 4, 5, 6])
# x軸の目盛り設定
# y軸の範囲設定 (全てのy値の最大値を取得して少し余裕を持たせる)
y_max = max([max(y) for y in y_lists])  # 各リストの最大値を取得して最大を選ぶ
plt.ylim(1, 1e6 * 1.5)  # y軸の下限は1（対数スケールなので0以下は使えない）

# 凡例を表示
plt.legend()

# グラフを表示
plt.show()

# %%
# yリストを7つ生成
y_lists = [
    [299.92, 2606.77, 23736, 220490.98],             # y1
    [88.57, 520.43, 3302.54, 21732.85],              # y2
    [54.12, 284.28, 1554.48, 8891.58],              # y3
    [37.59, 167.01, 809.8, 4065.04],              # y4
    [27.39, 112.16, 493.5, 2252.7],              # y5
    [25.66, 102.12, 440.13, 1957.95],              # y6
    [20.14, 77.44, 305.43, 1283.99]                # y7
]

y_name = ["ν = 1", "ν = 1/2", "ν = 0", "ν = -1", "ν = -3", "ν = -4", "ν = -100"]

# 色とラベルを設定
colors = ['red', 'darkorange', 'yellow', 'green', 'aqua', 'blue', 'purple']
labels = [f'{y_name[i]}' for i in range(7)]

# プロット
plt.figure(figsize=(8, 6))  # グラフのサイズを設定
for i, (y, color, label) in enumerate(zip(y_lists, colors, labels)):
    plt.semilogy(x, y, marker='o', linestyle='-', color=color, label=label)

plt.title('m = 3')

# x軸の目盛り設定
plt.xticks(ticks=[3, 4, 5, 6])
# y軸の範囲設定 (全てのy値の最大値を取得して少し余裕を持たせる)
y_max = max([max(y) for y in y_lists])  # 各リストの最大値を取得して最大を選ぶ
plt.ylim(1, 1e6 * 1.5)  # y軸の下限は1（対数スケールなので0以下は使えない）

# 凡例を表示
plt.legend()

# グラフを表示
plt.show()

# %%
# yリストを7つ生成
y_lists = [
    [606.31, 6718.7, 78720.38, 944450.02],             # y1
    [208.26, 1674.34, 14181.69, 124901.97],              # y2
    [136.06, 952.4, 7075, 54499.78],              # y3
    [95.52, 596.45, 3934.24, 27101.22],              # y4
    [72.93, 412.72, 2503.75, 15819.45],              # y5
    [68.23, 382.41, 2272.06, 14014.69],              # y6
    [56.51, 295.51, 1664.95, 9667.53]                # y7
]

y_name = ["ν = 1", "ν = 1/2", "ν = 0", "ν = -1", "ν = -3", "ν = -4", "ν = -100"]

# 色とラベルを設定
colors = ['red', 'darkorange', 'yellow', 'green', 'aqua', 'blue', 'purple']
labels = [f'{y_name[i]}' for i in range(7)]

# プロット
plt.figure(figsize=(8, 6))  # グラフのサイズを設定
for i, (y, color, label) in enumerate(zip(y_lists, colors, labels)):
    plt.semilogy(x, y, marker='o', linestyle='-', color=color, label=label)

plt.title('m = 4')

# x軸の目盛り設定
plt.xticks(ticks=[3, 4, 5, 6])
# y軸の範囲設定 (全てのy値の最大値を取得して少し余裕を持たせる)
y_max = max([max(y) for y in y_lists])  # 各リストの最大値を取得して最大を選ぶ
plt.ylim(1, 1e6 * 1.5)  # y軸の下限は1（対数スケールなので0以下は使えない）

# 凡例を表示
plt.legend()

# グラフを表示
plt.show()
